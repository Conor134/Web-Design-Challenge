# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
# from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data_cb/cities.csv"

# %%
cities_weather_df = pd.read_csv(r"C:\Users\byrne\Homework\Web-Design-Challenge\WebVisualizations\Resources/cities.csv")
cities_weather_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# 0    -57.76     89.60        6.93
# 1    169.85     42.61        5.64
# 2    149.72     44.32       10.11
# 3     78.62     59.89        0.94
# 4    147.90     32.17        2.95
# ..      ...       ...         ...
# 542   15.79     70.06        5.30
# 543  122.68     83.47       22.64
# 544  -80.02     76.90        4.63
# 545   18.34    104.53        4.97
# 546  -66.34     42.43        2.62
#
# [547 rows x 10 columns]

# %%
#Create Noerthn ans southern hemisphere datasets 
Northern_df = cities_weather_df.loc[(cities_weather_df["Lat"] >=0)].dropna()
Southern_df = cities_weather_df.loc[(cities_weather_df["Lat"] <0)].dropna()

Northern_df
Southern_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 6          6        hobart          20      AU  1528902000        87 -42.88
# 7          7   broken hill           0      AU  1528905311        88 -31.97
# ..       ...           ...         ...     ...         ...       ...    ...
# 528      528      santa fe          12      AR  1528905642        84 -31.62
# 531      531        sokoni           0      CD  1528905646        37 -12.89
# 535      535   brazzaville           8      CD  1528902000        55  -4.27
# 536      536        tutoia          40      BR  1528902000        52  -2.76
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# 0    -57.76     89.60        6.93
# 1    169.85     42.61        5.64
# 2    149.72     44.32       10.11
# 6    147.33     44.60        8.05
# 7    141.45     44.50        7.31
# ..      ...       ...         ...
# 528  -60.70     47.47       10.45
# 531   28.78     74.56        4.07
# 535   15.27     86.00        5.82
# 536  -42.27     91.40        8.05
# 546  -66.34     42.43        2.62
#
# [161 rows x 10 columns]

# %%
Northern_df
Southern_df
cities_weather_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# 0    -57.76     89.60        6.93
# 1    169.85     42.61        5.64
# 2    149.72     44.32       10.11
# 3     78.62     59.89        0.94
# 4    147.90     32.17        2.95
# ..      ...       ...         ...
# 542   15.79     70.06        5.30
# 543  122.68     83.47       22.64
# 544  -80.02     76.90        4.63
# 545   18.34    104.53        4.97
# 546  -66.34     42.43        2.62
#
# [547 rows x 10 columns]

# %%
#Temperature (C) vs. Latitude
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = cities_weather_df['Lat'].astype('float')
y_values = cities_weather_df['Max Temp'].astype('float')


# # Run linear regression
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)

# Plot regression line
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot

plt.xlabel('Latitude')
plt.ylabel('Temperature (C)')
plt.title("City latitiude vs. Max Temperature (01/05/17)")

# Print r square value
# print(f"R squared: {rvalue**2}")


# Save the figure
plt.tight_layout()
plt.savefig(r"C:\Users\byrne\Homework\Web-Design-Challenge\WebVisualizations\visualizations\LatvsTemp.png")

# Show plot
plt.show()

# %% [markdown]
# This plot shows that higher latitiudes are colder and that the northern hemisphere is warmer than the sourthern hemispher, which we know as it is summer in the northern hemispherere. It also should be norted that there are more cities inteh northern hemisphere.

# %%
#Humidity(%)  vs. Latitude
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = cities_weather_df['Lat'].astype('float')
y_values = cities_weather_df['Humidity'].astype('float')


# # Run linear regression
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)

# Plot regression line
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot

plt.xlabel('Latitude')
plt.ylabel("Humidity(%)")
plt.title("City latitiude vs. Humidity (01/05/17)")

# Print r square value
# print(f"R squared: {rvalue**2}")



# Save the figure
plt.tight_layout()
plt.savefig(r"C:\Users\byrne\Homework\Web-Design-Challenge\WebVisualizations\visualizations\LatvsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# This shows that the humidty appears to be well distributed across the hemispheres and that cities tend to be more humid than less humid.

# %%
#Cloudiness vs. Latitude
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = cities_weather_df['Lat'].astype('float')
y_values = cities_weather_df['Cloudiness'].astype('float')


# # Run linear regression
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)

# Plot regression line
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot

plt.xlabel('Latitude')
plt.ylabel("Cloudiness(%)")
plt.title("City latitiude vs. Cloudiness (01/05/17)")

# Print r square value
# print(f"R squared: {rvalue**2}")

# Save the figure
plt.tight_layout()

plt.savefig(r"C:\Users\byrne\Homework\Web-Design-Challenge\WebVisualizations\visualizations\LatvsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# The fact that there are "horiontal lines" across indicates that cloudiness is not an exact measurement and more subjective. there is a fairly even distribution across the hemispheres of all cloudiness ranges.

# %%
#Windspeed vs. Latitude
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = cities_weather_df['Lat'].astype('float')
y_values = cities_weather_df['Wind Speed'].astype('float')


# # Run linear regression
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(9,5))
plt.scatter(x_values,y_values)

# Plot regression line
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot

plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title("City latitiude vs. Windspeed (01/05/17)")


# Save the figure
plt.tight_layout()
plt.savefig(r"C:\Users\byrne\Homework\Web-Design-Challenge\WebVisualizations\visualizations\LatvsWindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# Fairly even distribution, with a few windy outliers.

# %% [markdown]
# Similar trend to the N-S plot. Again a very poor correltaion.

# %%
# output data to html
cities_weather_df.to_html('data.html')
